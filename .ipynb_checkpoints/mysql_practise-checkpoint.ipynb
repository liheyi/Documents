# %%
import pandas as pd
import MySQLdb as db
# %matplotlib inline
import matplotlib.pyplot as plt

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)
plt.rcParams['font.family'] = 'sans-serif'

conn = db.connect(host='localhost', user='root', passwd='dousan2014',db='pandas',charset='utf8')
df = pd.read_sql('select * from t_gold_pay_add', conn)
df[df['roleID'] == 541000134]
# Out:
#         id     roleID  vipLevel  gold  curGold        date  \
# 5       86  541000134         1  6480        0  2016-01-24
# 21     102  541000134         7  3280     6480  2016-01-24
# 23     104  541000134         8   300     9760  2016-01-24
# 24     105  541000134         8   500    10060  2016-01-24
# 194    275  541000134         8  1980    10240  2016-01-24
# 208    289  541000134         9    60    12220  2016-01-25
# 349    430  541000134         9  6480    12260  2016-01-25
# 405    486  541000134        10  1980    18740  2016-01-26
# 544    625  541000134        10  3280    20700  2016-01-26
# 597    678  541000134        10   500    23980  2016-01-27
# 675    756  541000134        10   680     1045  2016-01-27
# 732    813  541000134        10    60     1725  2016-01-28
# 818    899  541000134        10    60        7  2016-01-29
# 888    969  541000134        10    60       47  2016-01-30
# 943   1024  541000134        10  6480       22  2016-01-30
# ...

# %%
pay = df[df['roleID'] == 541000134].copy()
pay = pay[['date', 'gold']].copy()

# %%
paydate=pay.groupby('date').sum()
#paydate.sort_values('gold',ascending=False)
# Out:
#              gold
# date
# 2016-02-07  50020
# 2016-03-14  40440
# 2016-03-12  40400
# 2016-02-14  33300
# 2016-03-07  32920
# 2016-04-01  30280
# 2016-02-15  30020
# 2016-02-20  25980
# 2016-02-08  22780
# 2016-04-04  21180
# 2016-02-01  20320
# 2016-02-03  13260
# 2016-01-24  12540
# 2016-01-30  12100
# 2016-01-25   6540
# 2016-01-26   5260
# 2016-04-22   3280
# 2016-05-02   3280
# 2016-02-02   2100
# 2016-01-27   1180
# 2016-03-24    740
# 2016-04-06    560
# 2016-02-23    360
# 2016-04-08    360
# 2016-02-04    300
# 2016-04-16    300
# 2016-01-31    300
# 2016-03-18    120
# 2016-03-27     60
# 2016-03-28     60
# ...           ...
# 2016-02-12     60
# 2016-02-26     60
# 2016-02-11     60
# 2016-02-10     60
# 2016-02-09     60
# 2016-02-06     60
# 2016-02-05     60
# 2016-01-29     60
# 2016-01-28     60
# 2016-02-25     60
# 2016-02-27     60
# 2016-03-21     60
# 2016-03-09     60
# 2016-03-20     60
# 2016-03-19     60
# 2016-03-17     60
# 2016-03-16     60
# ...

# %%
paydate.plot()
